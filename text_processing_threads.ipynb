# %%
DyeSol_BeetR_-aft.txt
DyeSol_BeetR_-bf-senti_01.txt
DyeSol_BeetR_-bf-senti_02.txt
DyeSol_BlueB_-aft.txt
DyeSol_BlueB_-bf-senti-w-bg-spec_02.txt
DyeSol_BlueB_-bf-senti-w-bg-spec_03.txt
DyeSol_BlueB_-bf-senti-wo-bg-spec_01.txt
DyeSol_Tur_-aft.txt
DyeSol_Tur_01.txt
DyeSol_Tur_02.txt
DyeSol_Z907_-aft.txt
DyeSol_Z907_01.txt
DyeSol_Z907_02.txt
Glass_TiO2_01.txt
Glass_TiO2_02.txt
Glass_TiO2_03.txt
Glass_TiO2_04.txt
SC1_Z907_dark.txt
SC1_Z907_lighted.txt
SC2_fuckthez907new.txt
SC3_fucktheturmeric.txt
SC3_Tur_dark.txt
SC3_Tur_med-light.txt
SC4_Beet_dark.txt
SC4_Beet_med-light.txt
SC5_Blue.txt
SC5_Blue_large-light.txt
SC5_Blue_med-light.txt
SC5_Blue_med-lightTitle.txt
SC5_fucktheblueberry.txt
SentiGlass_14Nov_DC1_Z907new_01.txt
SentiGlass_14Nov_DC2_Z907old_01.txt
SentiGlass_14Nov_DC3_Blue_01.txt
SentiGlass_14Nov_DC4_BeetR_01.txt
SentiGlass_14Nov_DC5_Tur_01.txt
SentiGlass_14Nov_DC_Ref01.txt
SentiGlass_14Nov_HA1_01.txt
SentiGlass_14Nov_HA2_01.txt
SentiGlass_14Nov_HA3_01.txt
SentiGlass_14Nov_HA4_01.txt
SentiGlass_14Nov_HA5_01.txt

# %%
text = '''SentiGlass_14Nov_DC1_Z907new_01.txt
SentiGlass_14Nov_DC2_Z907old_01.txt
SentiGlass_14Nov_DC3_Blue_01.txt
SentiGlass_14Nov_DC4_BeetR_01.txt
SentiGlass_14Nov_DC5_Tur_01.txt
SentiGlass_14Nov_DC_Ref01.txt'''
text.split('.txt\n')
# Out:
# ['SentiGlass_14Nov_DC1_Z907new_01',
#  'SentiGlass_14Nov_DC2_Z907old_01',
#  'SentiGlass_14Nov_DC3_Blue_01',
#  'SentiGlass_14Nov_DC4_BeetR_01',
#  'SentiGlass_14Nov_DC5_Tur_01',
#  'SentiGlass_14Nov_DC_Ref01.txt']

# %%
splitedtext = text.split('.txt\n')
splitedtext = ['DyeSol_BeetR_-aft',
 'DyeSol_BeetR_-bf-senti_01',
 'DyeSol_BeetR_-bf-senti_02',
 'DyeSol_BlueB_-aft',
 'DyeSol_BlueB_-bf-senti-w-bg-spec_02',
 'DyeSol_BlueB_-bf-senti-w-bg-spec_03',
 'DyeSol_BlueB_-bf-senti-wo-bg-spec_01',
 'DyeSol_Tur_-aft',
 'DyeSol_Tur_01',
 'DyeSol_Tur_02',
 'DyeSol_Z907_-aft',
 'DyeSol_Z907_01',
 'DyeSol_Z907_02',
 'Glass_TiO2_01',
 'Glass_TiO2_02',
 'Glass_TiO2_03',
 'Glass_TiO2_04',
 'SC1_Z907_dark',
 'SentiGlass_14Nov_DC1_Z907new_01',
 'SentiGlass_14Nov_DC2_Z907old_01',
 'SentiGlass_14Nov_DC3_Blue_01',
 'SentiGlass_14Nov_DC4_BeetR_01',
 'SentiGlass_14Nov_DC5_Tur_01',
 'SentiGlass_14Nov_DC_Ref01',
 'SentiGlass_14Nov_HA1_01',
 'SentiGlass_14Nov_HA2_01',
 'SentiGlass_14Nov_HA3_01',
 'SentiGlass_14Nov_HA4_01',
 'SentiGlass_14Nov_HA5_01']

# %%
for i in splitedtext:
    x_part = 'x_'+ i
    y_part = 'y_' + i
    txt_part = i + '.txt'
    RHS = r"= load_d('"+txt_part+r"')"
    print(x_part,',',y_part,RHS)
# Out:
# x_DyeSol_BeetR_-aft , y_DyeSol_BeetR_-aft = load_d('DyeSol_BeetR_-aft.txt')
# x_DyeSol_BeetR_-bf-senti_01 , y_DyeSol_BeetR_-bf-senti_01 = load_d('DyeSol_BeetR_-bf-senti_01.txt')
# x_DyeSol_BeetR_-bf-senti_02 , y_DyeSol_BeetR_-bf-senti_02 = load_d('DyeSol_BeetR_-bf-senti_02.txt')
# x_DyeSol_BlueB_-aft , y_DyeSol_BlueB_-aft = load_d('DyeSol_BlueB_-aft.txt')
# x_DyeSol_BlueB_-bf-senti-w-bg-spec_02 , y_DyeSol_BlueB_-bf-senti-w-bg-spec_02 = load_d('DyeSol_BlueB_-bf-senti-w-bg-spec_02.txt')
# x_DyeSol_BlueB_-bf-senti-w-bg-spec_03 , y_DyeSol_BlueB_-bf-senti-w-bg-spec_03 = load_d('DyeSol_BlueB_-bf-senti-w-bg-spec_03.txt')
# x_DyeSol_BlueB_-bf-senti-wo-bg-spec_01 , y_DyeSol_BlueB_-bf-senti-wo-bg-spec_01 = load_d('DyeSol_BlueB_-bf-senti-wo-bg-spec_01.txt')
# x_DyeSol_Tur_-aft , y_DyeSol_Tur_-aft = load_d('DyeSol_Tur_-aft.txt')
# x_DyeSol_Tur_01 , y_DyeSol_Tur_01 = load_d('DyeSol_Tur_01.txt')
# x_DyeSol_Tur_02 , y_DyeSol_Tur_02 = load_d('DyeSol_Tur_02.txt')
# ...

# %%
import re as re
txt02 = '''x_DyeSol_BeetR_aft , y_DyeSol_BeetR_aft = load_d('DyeSol_BeetR_-aft.txt')
x_DyeSol_BeetR_bfsenti_01 , y_DyeSol_BeetR_bfsenti_01 = load_d('DyeSol_BeetR_-bf-senti_01.txt')
x_DyeSol_BeetR_bfsenti_02 , y_DyeSol_BeetR_bfsenti_02 = load_d('DyeSol_BeetR_-bf-senti_02.txt')
x_DyeSol_BlueB_aft , y_DyeSol_BlueB_aft = load_d('DyeSol_BlueB_-aft.txt')
x_DyeSol_BlueB_bfsentiwbg_02 , y_DyeSol_BlueB_bfsentiwbgspec_02 = load_d('DyeSol_BlueB_-bf-senti-w-bg-spec_02.txt')
x_DyeSol_BlueB_bfsentiwbgspec_03 , y_DyeSol_BlueB_bfsentiwbgspec_03 = load_d('DyeSol_BlueB_-bf-senti-w-bg-spec_03.txt')
x_DyeSol_BlueB_bfsentiwobgspec_01 , y_DyeSol_BlueB_bfsentiwobgspec_01 = load_d('DyeSol_BlueB_-bf-senti-wo-bg-spec_01.txt')
x_DyeSol_Tur_aft , y_DyeSol_Tur_aft = load_d('DyeSol_Tur_-aft.txt')
x_DyeSol_Tur_01 , y_DyeSol_Tur_01 = load_d('DyeSol_Tur_01.txt')
x_DyeSol_Tur_02 , y_DyeSol_Tur_02 = load_d('DyeSol_Tur_02.txt')
x_DyeSol_Z907_aft , y_DyeSol_Z907_aft = load_d('DyeSol_Z907_-aft.txt')
x_DyeSol_Z907_01 , y_DyeSol_Z907_01 = load_d('DyeSol_Z907_01.txt')
x_DyeSol_Z907_02 , y_DyeSol_Z907_02 = load_d('DyeSol_Z907_02.txt')
x_Glass_TiO2_01 , y_Glass_TiO2_01 = load_d('Glass_TiO2_01.txt')
x_Glass_TiO2_02 , y_Glass_TiO2_02 = load_d('Glass_TiO2_02.txt')
x_Glass_TiO2_03 , y_Glass_TiO2_03 = load_d('Glass_TiO2_03.txt')
x_Glass_TiO2_04 , y_Glass_TiO2_04 = load_d('Glass_TiO2_04.txt')
x_SentiGlass_14Nov_DC1_Z907new_01 , y_SentiGlass_14Nov_DC1_Z907new_01 = load_d('SentiGlass_14Nov_DC1_Z907new_01.txt')
x_SentiGlass_14Nov_DC2_Z907old_01 , y_SentiGlass_14Nov_DC2_Z907old_01 = load_d('SentiGlass_14Nov_DC2_Z907old_01.txt')
x_SentiGlass_14Nov_DC3_Blue_01 , y_SentiGlass_14Nov_DC3_Blue_01 = load_d('SentiGlass_14Nov_DC3_Blue_01.txt')
x_SentiGlass_14Nov_DC4_BeetR_01 , y_SentiGlass_14Nov_DC4_BeetR_01 = load_d('SentiGlass_14Nov_DC4_BeetR_01.txt')
x_SentiGlass_14Nov_DC5_Tur_01 , y_SentiGlass_14Nov_DC5_Tur_01 = load_d('SentiGlass_14Nov_DC5_Tur_01.txt')
x_SentiGlass_14Nov_DC_Ref01 , y_SentiGlass_14Nov_DC_Ref01 = load_d('SentiGlass_14Nov_DC_Ref01.txt')
x_SentiGlass_14Nov_HA1_01 , y_SentiGlass_14Nov_HA1_01 = load_d('SentiGlass_14Nov_HA1_01.txt')
x_SentiGlass_14Nov_HA2_01 , y_SentiGlass_14Nov_HA2_01 = load_d('SentiGlass_14Nov_HA2_01.txt')
x_SentiGlass_14Nov_HA3_01 , y_SentiGlass_14Nov_HA3_01 = load_d('SentiGlass_14Nov_HA3_01.txt')
x_SentiGlass_14Nov_HA4_01 , y_SentiGlass_14Nov_HA4_01 = load_d('SentiGlass_14Nov_HA4_01.txt')
x_SentiGlass_14Nov_HA5_01 , y_SentiGlass_14Nov_HA5_01 = load_d('SentiGlass_14Nov_HA5_01.txt')'''
txt02.replace(' , ',' ').replace(' = load_d(',' ').replace(')\n',' ').split(' ')
# Out:
# ['x_DyeSol_BeetR_aft',
#  'y_DyeSol_BeetR_aft',
#  "'DyeSol_BeetR_-aft.txt'",
#  'x_DyeSol_BeetR_bfsenti_01',
#  'y_DyeSol_BeetR_bfsenti_01',
#  "'DyeSol_BeetR_-bf-senti_01.txt'",
#  'x_DyeSol_BeetR_bfsenti_02',
#  'y_DyeSol_BeetR_bfsenti_02',
#  "'DyeSol_BeetR_-bf-senti_02.txt'",
#  'x_DyeSol_BlueB_aft',
#  'y_DyeSol_BlueB_aft',
#  "'DyeSol_BlueB_-aft.txt'",
#  'x_DyeSol_BlueB_bfsentiwbg_02',
#  'y_DyeSol_BlueB_bfsentiwbgspec_02',
#  "'DyeSol_BlueB_-bf-senti-w-bg-spec_02.txt'",
#  'x_DyeSol_BlueB_bfsentiwbgspec_03',
#  'y_DyeSol_BlueB_bfsentiwbgspec_03',
#  "'DyeSol_BlueB_-bf-senti-w-bg-spec_03.txt'",
#  'x_DyeSol_BlueB_bfsentiwobgspec_01',
#  'y_DyeSol_BlueB_bfsentiwobgspec_01',
#  "'DyeSol_BlueB_-bf-senti-wo-bg-spec_01.txt'",
#  'x_DyeSol_Tur_aft',
#  'y_DyeSol_Tur_aft',
#  "'DyeSol_Tur_-aft.txt'",
#  'x_DyeSol_Tur_01',
#  'y_DyeSol_Tur_01',
#  "'DyeSol_Tur_01.txt'",
#  'x_DyeSol_Tur_02',
#  'y_DyeSol_Tur_02',
#  "'DyeSol_Tur_02.txt'",
#  'x_DyeSol_Z907_aft',
# ...

# %%
txt03 = ['x_DyeSol_BeetR_aft',
 'y_DyeSol_BeetR_aft',
 "'DyeSol_BeetR_-aft.txt'",
 'x_DyeSol_BeetR_bfsenti_01',
 'y_DyeSol_BeetR_bfsenti_01',
 "'DyeSol_BeetR_-bf-senti_01.txt'",
 'x_DyeSol_BeetR_bfsenti_02',
 'y_DyeSol_BeetR_bfsenti_02',
 "'DyeSol_BeetR_-bf-senti_02.txt'",
 'x_DyeSol_BlueB_aft',
 'y_DyeSol_BlueB_aft',
 "'DyeSol_BlueB_-aft.txt'",
 'x_DyeSol_BlueB_bfsentiwbg_02',
 'y_DyeSol_BlueB_bfsentiwbgspec_02',
 "'DyeSol_BlueB_-bf-senti-w-bg-spec_02.txt'",
 'x_DyeSol_BlueB_bfsentiwbgspec_03',
 'y_DyeSol_BlueB_bfsentiwbgspec_03',
 "'DyeSol_BlueB_-bf-senti-w-bg-spec_03.txt'",
 'x_DyeSol_BlueB_bfsentiwobgspec_01',
 'y_DyeSol_BlueB_bfsentiwobgspec_01',
 "'DyeSol_BlueB_-bf-senti-wo-bg-spec_01.txt'",
 'x_DyeSol_Tur_aft',
 'y_DyeSol_Tur_aft',
 "'DyeSol_Tur_-aft.txt'",
 'x_DyeSol_Tur_01',
 'y_DyeSol_Tur_01',
 "'DyeSol_Tur_01.txt'",
 'x_DyeSol_Tur_02',
 'y_DyeSol_Tur_02',
 "'DyeSol_Tur_02.txt'",
 'x_DyeSol_Z907_aft',
 'y_DyeSol_Z907_aft',
 "'DyeSol_Z907_-aft.txt'",
 'x_DyeSol_Z907_01',
 'y_DyeSol_Z907_01',
 "'DyeSol_Z907_01.txt'",
 'x_DyeSol_Z907_02',
 'y_DyeSol_Z907_02',
 "'DyeSol_Z907_02.txt'",
 'x_Glass_TiO2_01',
 'y_Glass_TiO2_01',
 "'Glass_TiO2_01.txt'",
 'x_Glass_TiO2_02',
 'y_Glass_TiO2_02',
 "'Glass_TiO2_02.txt'",
 'x_Glass_TiO2_03',
 'y_Glass_TiO2_03',
 "'Glass_TiO2_03.txt'",
 'x_Glass_TiO2_04',
 'y_Glass_TiO2_04',
 "'Glass_TiO2_04.txt'",
 'x_SentiGlass_14Nov_DC1_Z907new_01',
 'y_SentiGlass_14Nov_DC1_Z907new_01',
 "'SentiGlass_14Nov_DC1_Z907new_01.txt'",
 'x_SentiGlass_14Nov_DC2_Z907old_01',
 'y_SentiGlass_14Nov_DC2_Z907old_01',
 "'SentiGlass_14Nov_DC2_Z907old_01.txt'",
 'x_SentiGlass_14Nov_DC3_Blue_01',
 'y_SentiGlass_14Nov_DC3_Blue_01',
 "'SentiGlass_14Nov_DC3_Blue_01.txt'",
 'x_SentiGlass_14Nov_DC4_BeetR_01',
 'y_SentiGlass_14Nov_DC4_BeetR_01',
 "'SentiGlass_14Nov_DC4_BeetR_01.txt'",
 'x_SentiGlass_14Nov_DC5_Tur_01',
 'y_SentiGlass_14Nov_DC5_Tur_01',
 "'SentiGlass_14Nov_DC5_Tur_01.txt'",
 'x_SentiGlass_14Nov_DC_Ref01',
 'y_SentiGlass_14Nov_DC_Ref01',
 "'SentiGlass_14Nov_DC_Ref01.txt'",
 'x_SentiGlass_14Nov_HA1_01',
 'y_SentiGlass_14Nov_HA1_01',
 "'SentiGlass_14Nov_HA1_01.txt'",
 'x_SentiGlass_14Nov_HA2_01',
 'y_SentiGlass_14Nov_HA2_01',
 "'SentiGlass_14Nov_HA2_01.txt'",
 'x_SentiGlass_14Nov_HA3_01',
 'y_SentiGlass_14Nov_HA3_01',
 "'SentiGlass_14Nov_HA3_01.txt'",
 'x_SentiGlass_14Nov_HA4_01',
 'y_SentiGlass_14Nov_HA4_01',
 "'SentiGlass_14Nov_HA4_01.txt'",
 'x_SentiGlass_14Nov_HA5_01',
 'y_SentiGlass_14Nov_HA5_01',
 "'SentiGlass_14Nov_HA5_01.txt'"]

# %%
len(txt03)/3
# Out:
# 28.0

# %%
for i in range(int(len(txt03)/3)):
    header = 'plt.plot(' + txt03[3*i] + ' , ' + txt03[3*i+1]
    modifier = ", marker='.', linestyle=''"
    label = ', label =' + txt03[3*i+2]
    tail = ')'
    print(header,modifier,label,tail)
# Out:
# plt.plot(x_DyeSol_BeetR_aft , y_DyeSol_BeetR_aft , marker='.', linestyle='' , label ='DyeSol_BeetR_-aft.txt' )
# plt.plot(x_DyeSol_BeetR_bfsenti_01 , y_DyeSol_BeetR_bfsenti_01 , marker='.', linestyle='' , label ='DyeSol_BeetR_-bf-senti_01.txt' )
# plt.plot(x_DyeSol_BeetR_bfsenti_02 , y_DyeSol_BeetR_bfsenti_02 , marker='.', linestyle='' , label ='DyeSol_BeetR_-bf-senti_02.txt' )
# plt.plot(x_DyeSol_BlueB_aft , y_DyeSol_BlueB_aft , marker='.', linestyle='' , label ='DyeSol_BlueB_-aft.txt' )
# plt.plot(x_DyeSol_BlueB_bfsentiwbg_02 , y_DyeSol_BlueB_bfsentiwbgspec_02 , marker='.', linestyle='' , label ='DyeSol_BlueB_-bf-senti-w-bg-spec_02.txt' )
# plt.plot(x_DyeSol_BlueB_bfsentiwbgspec_03 , y_DyeSol_BlueB_bfsentiwbgspec_03 , marker='.', linestyle='' , label ='DyeSol_BlueB_-bf-senti-w-bg-spec_03.txt' )
# plt.plot(x_DyeSol_BlueB_bfsentiwobgspec_01 , y_DyeSol_BlueB_bfsentiwobgspec_01 , marker='.', linestyle='' , label ='DyeSol_BlueB_-bf-senti-wo-bg-spec_01.txt' )
# ...
