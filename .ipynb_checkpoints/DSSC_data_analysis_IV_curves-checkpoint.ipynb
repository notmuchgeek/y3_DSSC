# %%
# %pylab inline
import pandas as pd
from scipy.signal import find_peaks
import plotly.graph_objects as go

import matplotlib.pyplot as plt
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os

#Universal path for the working dictionary
PATH = 'C:/Users/AlbertCielstian/Documents/GitHub/y3_DSSC/all_plot_datasets/'

files = os.listdir(PATH)

for file in files:
    print(file)

# %%
def load_d(name):
    xy_data=np.loadtxt(PATH+str(name),skiprows=0)

    x1=[]
    y1=[]
    for i in xy_data:
        x1.append(i[0])
        y1.append(i[1])
    return np.array(x1), np.array(y1)

# %%
x_Z907_dk, y_Z907_dk = load_d('SC1_Z907_dark.txt')
x_Z907_lgt, y_Z907_lgt = load_d('SC1_Z907_lighted.txt')

x_Tur_dk, y_Tur_dk = load_d('SC3_Tur_dark.txt')
x_Tur_lgt, y_Tur_lgt = load_d('SC3_Tur_med-light.txt')

x_Beet_dk, y_Beet_dk = load_d('SC4_Beet_dark.txt')
x_Beet_lgt, y_Beet_lgt = load_d('SC4_Beet_med-light.txt')

x_Blue_dk, y_Blue_dk = load_d('SC5_Blue.txt')
x_Blue_lgt, y_Blue_lgt = load_d('SC5_Blue_med-light.txt') # not using SC5_Blue_large-light.txt here

# %% [markdown]
# # Get the x/y intercepted points for a line from two coordinations

# %%
a,b,p,q=map(float,input('Enter the coordinates of the points:').split())

m=(q-b)/(p-a)
y=b
x=a
c=y-(m*x)

#to find x-intercept.
y=0
x=(y-c)/m
print('x-intercept of the line:',x)

'''
#to find y-intercept.
x=0
y=(m*x)+c
print('y-intercept of the line:',y)'''
# Out:
# Enter the coordinates of the points:-0.100000000 -6.779010000E-6 -0.050000000 1.358589000E-9
# x-intercept of the line: -0.0500100185482704
# "\n#to find y-intercept.\nx=0\ny=(m*x)+c\nprint('y-intercept of the line:',y)"

# %% [markdown]
# # Plot all the I-V Curve

# %%
fig, ax = plt.subplots()
ax.plot(x_Z907_dk, y_Z907_dk, linewidth=1,label = 'Z907 dark', marker='.')
ax.plot(x_Z907_lgt, y_Z907_lgt, linewidth=1,label = 'Z907 lighted', marker='.')

ax.set_xlabel('Voltage (V)')
ax.set_ylabel('Current (A)')

ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

ax.legend()

# %%
fig, ax = plt.subplots()
ax.plot(x_Tur_dk, y_Tur_dk, linewidth=3,label = 'Tur dark')
ax.plot(x_Tur_lgt, y_Tur_lgt, linewidth=3,label = 'Tur lighted')

ax.set_xlabel('Voltage (V)')
ax.set_ylabel('Current (A)')

ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

#ax.set_xlim(0,0.3)

ax.legend()

# %%
fig, ax = plt.subplots()
ax.plot(x_Beet_dk, y_Beet_dk, linewidth=3,label = 'Beet dark')
ax.plot(x_Beet_lgt, y_Beet_lgt, linewidth=3,label = 'Beet lighted')

ax.set_xlabel('Voltage (V)')
ax.set_ylabel('Current (A)')

ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.legend()

# %%
fig, ax = plt.subplots()
ax.plot(x_Blue_dk, y_Blue_dk, linewidth=3,label = 'Blue dark')
ax.plot(x_Blue_lgt, y_Blue_lgt, linewidth=3,label = 'Blue lighted')

#ax.set_yticks(np.arange(0, 0.003, step=0.0005))

ax.set_xlabel('Voltage (V)')
ax.set_ylabel('Current (A)')
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.legend()

# %%
x_Z907_fk, y_Z907_fk = load_d('SC2_fuckthez907new.txt')


fig, ax = plt.subplots()
ax.plot(x_Z907_fk, y_Z907_fk, linewidth=3,label = 'Z907 fuck')

#ax.set_yticks(np.arange(0, 0.003, step=0.0005))

ax.set_xlabel('Voltage (V)')
ax.set_ylabel('Current (A)')
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.legend()

# %%
x_Tur_fk, y_Tur_fk = load_d('SC3_fucktheturmeric.txt')

fig, ax = plt.subplots()
ax.plot(x_Tur_fk, y_Tur_fk, linewidth=3,label = 'Tur Fuck')

#ax.set_yticks(np.arange(0, 0.003, step=0.0005))

ax.set_xlabel('Voltage (V)')
ax.set_ylabel('Current (A)')
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.legend()

# %%
x_Blue_fk, y_Blue_fk = load_d('SC5_fucktheblueberry.txt')


fig, ax = plt.subplots()
ax.plot(x_Blue_dk, y_Blue_dk, linewidth=3,label = 'Blue Fuck')

#ax.set_yticks(np.arange(0, 0.003, step=0.0005))

ax.set_xlabel('Voltage (V)')
ax.set_ylabel('Current (A)')
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.legend()

# %% [markdown]
# # Find the maximum area under the curve

# %%
# See the jupyter notebook: Finding the Maximum Area Under Points on a Curve in Python.ipynb
